# %%
import pandas as pd

# %%
sales = pd.read_csv("TechNova_Sales_Data.csv")

# %%
sales.head()
# Out:
#    Order_Date   Product     Category Region  Quantity   Sales  Profit
# 0  2026-01-05    Laptop  Electronics  North         2  120000   18000
# 1  2026-01-08     Mouse  Accessories  South        10    8000    2400
# 2  2026-01-12  Keyboard  Accessories   East         7   10500    3150
# 3  2026-01-18   Monitor  Electronics   West         3   45000    9000
# 4  2026-02-03    Laptop  Electronics  South         1   60000    9000

# %%
sales.shape
# Out:
# (20, 7)

# %%
sales.columns
# Out:
# Index(['Order_Date', 'Product', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='str')

# %%
sales.isnull().sum()
# Out:
# Order_Date    0
# Product       0
# Category      0
# Region        0
# Quantity      0
# Sales         0
# Profit        0
# dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_Date  20 non-null     str
#  1   Product     20 non-null     str
#  2   Category    20 non-null     str
#  3   Region      20 non-null     str
#  4   Quantity    20 non-null     int64
#  5   Sales       20 non-null     int64
#  6   Profit      20 non-null     int64
# dtypes: int64(3), str(4)
# memory usage: 1.9 KB

# %%
sales.describe()
# Out:
#         Quantity          Sales        Profit
# count  20.000000      20.000000     20.000000
# mean    6.150000   40290.000000   7587.000000
# std     4.380279   38771.542738   5189.501649
# min     1.000000    8000.000000   2400.000000
# 25%     2.000000   12000.000000   3600.000000
# 50%     5.500000   19500.000000   5700.000000
# 75%     9.250000   60000.000000   9000.000000
# max    15.000000  120000.000000  18000.000000

# %%
sales["Sales"].sum()
# Out:
# np.int64(805800)

# %%
sales["Profit"].sum()
# Out:
# np.int64(151740)

# %%
sales.groupby("Product")
["Sales"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 sales.groupby("Product")
# ----> 2 ["Sales"].sum().sort_values(ascending=False)
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
sales.groupby("Product")["Sales"].sum().sort_values(ascending=False)
# Out:
# Product
# Laptop        480000
# Monitor       180000
# Headphones     54000
# Keyboard       51000
# Mouse          40800
# Name: Sales, dtype: int64

# %%
sales.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# South    320000
# North    203100
# West     149200
# East     133500
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
category_sales = sales.groupby("Category")["Sales"].sum()

category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
region_sales = sales.groupby("Region")["Sales"].sum()

region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
sales["Order_Date"] = pd.to_datetime(sales["Order_Date"])

daily_sales = sales.groupby("Order_Date")["Sales"].sum()

daily_sales.plot(kind="line")
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
pivot = pd.pivot_table(
    sales,
    values="Sales",
    index="Category",
    columns="Region",
    aggfunc="sum",
    fill_value=0
)

pivot
# Out:
# Region        East   North   South    West
# Category
# Accessories  43500   38100   20000   44200
# Electronics  90000  165000  300000  105000
